# %%
import tensorflow as tf
from helpers import batch_index_groups, dtype
import mnist_data
import vae as vae

# %%
train_total_data, _, _, _, test_data, test_labels = mnist_data.prepare_MNIST_data()

train_size = 10000
IMAGE_SIZE_MNIST = 28
num_hidden = 500
dim_img = IMAGE_SIZE_MNIST ** 2
#784 dimension
dim_z = 2
learn_rate = 1e-3
batch_size = min(128, train_size)
num_epochs = 100

y_input = tf.placeholder(dtype, shape=[None, dim_img], name='input_img')
y_output_true = tf.placeholder(dtype, shape=[None, dim_img], name='target_img')

# dropout
keep_prob = tf.placeholder(dtype, name='keep_prob')

# network architecture
ae = vae.autoencoder(
    y_input=y_input,
    y_output_true=y_output_true,
    dim_img=dim_img,
    dim_z=dim_z,
    num_hidden=num_hidden,
    keep_prob=keep_prob
)

# optimization
train_step = tf.train.AdamOptimizer(learn_rate).minimize(ae.loss) #minimize loss

y_train = train_total_data[:train_size, :-mnist_data.NUM_LABELS]
y_train_labels = train_total_data[:train_size, -mnist_data.NUM_LABELS:]
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


print("Num data points", train_size)
print("Num epochs", num_epochs)

with tf.Session() as session:

    session.run(tf.global_variables_initializer())
    session.graph.finalize()

    for epoch in range(num_epochs):
        for i, batch_indices in enumerate(batch_index_groups(batch_size=batch_size, num_samples=train_size)):

            batch_xs_input = y_train[batch_indices, :]

            _, tot_loss, loss_likelihood, loss_divergence, y_output = session.run(
                (
                    train_step,
                    ae.loss,
                    ae.neg_marginal_likelihood,
                    ae.kl_divergence,
                    ae.y_output
                ),
                feed_dict={
                    y_input: batch_xs_input,
                    y_output_true: batch_xs_input,
                    keep_prob: 0.9
                }
            )

        print(
            "epoch %d: L_tot %03.2f L_likelihood %03.2f L_divergence %03.2f" % (
                epoch,
                tot_loss,
                loss_likelihood,
                loss_divergence,

            )
        )
        fig, ax = plt.subplots(
            nrows=5,
            ncols=5,
            sharex=True,
            sharey=True, )
        ax = ax.flatten()
        for ii in range(25):
            img = y_output[ii].reshape(28, 28)
            ax[ii].imshow(img, cmap='Greys', interpolation='nearest')
        
        ax[0].set_xticks([])
        ax[0].set_yticks([])
        plt.tight_layout()
        plt.savefig('./Q10/%s.png' % str(epoch),  bbox_inches='tight', pad_inches=0)
        plt.show();
# Out:
# Num data points 10000
# Num epochs 100
# epoch 0: L_tot 207.55 L_likelihood 202.47 L_divergence 5.08
# epoch 1: L_tot 219.81 L_likelihood 212.11 L_divergence 7.70
# epoch 2: L_tot 194.70 L_likelihood 189.61 L_divergence 5.09
# epoch 3: L_tot 194.82 L_likelihood 188.41 L_divergence 6.42
# epoch 4: L_tot 191.44 L_likelihood 184.39 L_divergence 7.06
# epoch 5: L_tot 178.41 L_likelihood 171.00 L_divergence 7.41
# epoch 6: L_tot 180.75 L_likelihood 173.31 L_divergence 7.44
# epoch 7: L_tot 189.74 L_likelihood 181.00 L_divergence 8.74
# epoch 8: L_tot 177.88 L_likelihood 170.49 L_divergence 7.39
# epoch 9: L_tot 190.88 L_likelihood 180.89 L_divergence 9.99
# epoch 10: L_tot 189.04 L_likelihood 182.71 L_divergence 6.33
# epoch 11: L_tot 173.90 L_likelihood 167.42 L_divergence 6.48
# epoch 12: L_tot 172.49 L_likelihood 165.87 L_divergence 6.62
# epoch 13: L_tot 176.28 L_likelihood 170.23 L_divergence 6.06
# epoch 14: L_tot 176.45 L_likelihood 170.18 L_divergence 6.27
# epoch 15: L_tot 165.34 L_likelihood 159.23 L_divergence 6.12
# epoch 16: L_tot 170.03 L_likelihood 163.56 L_divergence 6.46
# epoch 17: L_tot 170.15 L_likelihood 163.64 L_divergence 6.51
# epoch 18: L_tot 167.40 L_likelihood 161.18 L_divergence 6.22
# epoch 19: L_tot 165.03 L_likelihood 158.98 L_divergence 6.05
# epoch 20: L_tot 165.33 L_likelihood 159.25 L_divergence 6.07
# epoch 21: L_tot 169.39 L_likelihood 163.15 L_divergence 6.24
# epoch 22: L_tot 158.45 L_likelihood 152.00 L_divergence 6.45
# epoch 23: L_tot 166.32 L_likelihood 160.01 L_divergence 6.31
# epoch 24: L_tot 164.68 L_likelihood 158.50 L_divergence 6.17
# epoch 25: L_tot 160.73 L_likelihood 154.79 L_divergence 5.94
# epoch 26: L_tot 159.54 L_likelihood 153.81 L_divergence 5.73
# epoch 27: L_tot 158.60 L_likelihood 152.58 L_divergence 6.02
# epoch 28: L_tot 161.10 L_likelihood 155.24 L_divergence 5.86
# epoch 29: L_tot 158.57 L_likelihood 152.61 L_divergence 5.96
# epoch 30: L_tot 155.47 L_likelihood 149.36 L_divergence 6.11
# epoch 31: L_tot 159.35 L_likelihood 153.28 L_divergence 6.08
# epoch 32: L_tot 163.16 L_likelihood 157.30 L_divergence 5.86
# epoch 33: L_tot 160.64 L_likelihood 154.46 L_divergence 6.18
# epoch 34: L_tot 158.01 L_likelihood 151.93 L_divergence 6.08
# epoch 35: L_tot 157.59 L_likelihood 151.62 L_divergence 5.97
# epoch 36: L_tot 162.76 L_likelihood 157.01 L_divergence 5.75
# epoch 37: L_tot 155.50 L_likelihood 149.25 L_divergence 6.25
# epoch 38: L_tot 154.29 L_likelihood 148.13 L_divergence 6.17
# epoch 39: L_tot 155.21 L_likelihood 148.98 L_divergence 6.23
# epoch 40: L_tot 159.04 L_likelihood 152.66 L_divergence 6.38
# epoch 41: L_tot 158.95 L_likelihood 152.85 L_divergence 6.09
# epoch 42: L_tot 163.58 L_likelihood 157.32 L_divergence 6.26
# epoch 43: L_tot 156.34 L_likelihood 150.37 L_divergence 5.97
# epoch 44: L_tot 160.23 L_likelihood 153.88 L_divergence 6.35
# epoch 45: L_tot 153.05 L_likelihood 147.44 L_divergence 5.61
# epoch 46: L_tot 155.51 L_likelihood 149.24 L_divergence 6.27
# epoch 47: L_tot 161.54 L_likelihood 155.45 L_divergence 6.09
# epoch 48: L_tot 148.86 L_likelihood 142.45 L_divergence 6.41
# epoch 49: L_tot 157.36 L_likelihood 150.92 L_divergence 6.44
# epoch 50: L_tot 155.34 L_likelihood 149.25 L_divergence 6.09
# epoch 51: L_tot 157.91 L_likelihood 151.39 L_divergence 6.52
# epoch 52: L_tot 157.00 L_likelihood 150.73 L_divergence 6.27
# epoch 53: L_tot 154.77 L_likelihood 148.50 L_divergence 6.28
# epoch 54: L_tot 149.75 L_likelihood 143.19 L_divergence 6.56
# epoch 55: L_tot 149.21 L_likelihood 142.68 L_divergence 6.53
# epoch 56: L_tot 150.52 L_likelihood 143.73 L_divergence 6.79
# epoch 57: L_tot 143.04 L_likelihood 136.72 L_divergence 6.32
# epoch 58: L_tot 160.10 L_likelihood 153.93 L_divergence 6.16
# epoch 59: L_tot 155.36 L_likelihood 148.84 L_divergence 6.52
# epoch 60: L_tot 150.87 L_likelihood 144.43 L_divergence 6.44
# epoch 61: L_tot 146.31 L_likelihood 139.82 L_divergence 6.49
# epoch 62: L_tot 151.95 L_likelihood 145.66 L_divergence 6.29
# epoch 63: L_tot 151.11 L_likelihood 144.73 L_divergence 6.38
# epoch 64: L_tot 150.78 L_likelihood 144.33 L_divergence 6.45
# epoch 65: L_tot 154.27 L_likelihood 147.81 L_divergence 6.46
# epoch 66: L_tot 157.42 L_likelihood 151.36 L_divergence 6.05
# epoch 67: L_tot 147.90 L_likelihood 141.44 L_divergence 6.47
# epoch 68: L_tot 154.79 L_likelihood 148.27 L_divergence 6.52
# epoch 69: L_tot 150.19 L_likelihood 143.82 L_divergence 6.38
# epoch 70: L_tot 154.44 L_likelihood 148.06 L_divergence 6.37
# epoch 71: L_tot 151.64 L_likelihood 145.02 L_divergence 6.61
# epoch 72: L_tot 155.69 L_likelihood 149.26 L_divergence 6.43
# epoch 73: L_tot 148.04 L_likelihood 141.57 L_divergence 6.47
# epoch 74: L_tot 158.48 L_likelihood 152.27 L_divergence 6.21
# epoch 75: L_tot 151.41 L_likelihood 145.26 L_divergence 6.15
# epoch 76: L_tot 150.62 L_likelihood 143.84 L_divergence 6.78
# epoch 77: L_tot 142.63 L_likelihood 135.92 L_divergence 6.71
# epoch 78: L_tot 152.64 L_likelihood 146.45 L_divergence 6.19
# epoch 79: L_tot 150.24 L_likelihood 143.54 L_divergence 6.71
# epoch 80: L_tot 143.94 L_likelihood 137.44 L_divergence 6.50
# epoch 81: L_tot 145.83 L_likelihood 139.22 L_divergence 6.61
# epoch 82: L_tot 153.46 L_likelihood 147.21 L_divergence 6.25
# epoch 83: L_tot 151.67 L_likelihood 145.33 L_divergence 6.34
# epoch 84: L_tot 147.66 L_likelihood 141.35 L_divergence 6.31
# epoch 85: L_tot 154.43 L_likelihood 148.06 L_divergence 6.37
# epoch 86: L_tot 149.67 L_likelihood 142.96 L_divergence 6.71
# epoch 87: L_tot 155.94 L_likelihood 149.94 L_divergence 6.00
# epoch 88: L_tot 145.87 L_likelihood 139.31 L_divergence 6.56
# epoch 89: L_tot 145.64 L_likelihood 138.91 L_divergence 6.73
# epoch 90: L_tot 149.46 L_likelihood 142.60 L_divergence 6.87
# epoch 91: L_tot 141.53 L_likelihood 134.79 L_divergence 6.74
# epoch 92: L_tot 154.10 L_likelihood 147.57 L_divergence 6.53
# epoch 93: L_tot 143.53 L_likelihood 136.83 L_divergence 6.70
# epoch 94: L_tot 154.73 L_likelihood 148.18 L_divergence 6.55
# epoch 95: L_tot 150.25 L_likelihood 143.66 L_divergence 6.58
# epoch 96: L_tot 144.08 L_likelihood 137.75 L_divergence 6.33
# epoch 97: L_tot 151.84 L_likelihood 145.51 L_divergence 6.33
# epoch 98: L_tot 150.17 L_likelihood 143.73 L_divergence 6.44
# epoch 99: L_tot 144.80 L_likelihood 138.21 L_divergence 6.59
